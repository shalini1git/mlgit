# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Basic Concepts

# %% [markdown]
# # Terminology
# Machine Learning, Data Science, Data Mining, Data Analysis, Sta-
# tistical Learning, Knowledge Discovery in Databases, Pattern Dis-
# covery.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Data everywhere!

# %% [markdown]
# 1. Google: processes 24 peta bytes of data per day.
# 2. Facebook: 10 million photos uploaded every hour.
# 3. Youtube: 1 hour of video uploaded every second.
# 4. Twitter: 400 million tweets per day.
# 5. Astronomy: Satellite data is in hundreds of PB.

# %% [markdown]
# In 2020 the digital universe has already reach 44
# zettabytes..."
# That's 44 trillion gigabytes!

# %% [markdown]
# # Data types

# %% [markdown]
# Data comes in different sizes and also flavors (types):
#
#  Texts
#
#  Numbers
#
#  Clickstreams
#
#  Graphs
#
#  Tables
#
#  Images
#
#  Transactions
#
#  Videos
#
#  Some or all of the above!

# %% [markdown]
# # Smile, we are 'DATAFIED'!

# %% [markdown]
#  Wherever we go, we are \datafied".
#
#  Smartphones are tracking our locations.
#
#  We leave a data trail in our web browsing.
#
#  Interaction in social networks.
#
#  Privacy is an important issue in Data Science.

# %% [markdown]
# # The Data Science process

# %% [markdown]
# # ![pi.png](attachment:pi.png)

# %% [markdown]
# # Applications of ML

# %% [markdown]
# We all use it on a daily basis.
#
# Examples:
#
#  Spam fltering
#
#  Credit card fraud detection
#
#  Digit recognition on checks, zip codes
#
#  Detecting faces in images
#
#  MRI image analysis
#
#  Recommendation system
#
#  Search engines
#
#  Handwriting recognition
#
#  Scene classification
#
#  etc...

# %% [markdown]
# # Interdisciplinary field

# %% [markdown]
# # ![pic.png](attachment:pic.png)

# %% [markdown]
# # Machine Learning definition

# %% [markdown]
# # "How do we create computer programs that improve with experience?"

# %% [markdown]
# # "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P, if its performance at tasks in T, as measured by P, improves with experience E. "
#
# Tom Mitchell. Machine Learning 1997.

# %% [markdown]
# # Machine Learning – Categories of Machine Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Machine learning evolved from left to right as shown in the above diagram.
#
#  Initially, researchers started out with Supervised Learning. This is the case of housing price prediction.
#
#  This was followed by unsupervised learning, where the machine is made to learn on its own without any supervision.
#
#  Scientists discovered further that it may be a good idea to reward the machine when it does the job the expected way and there came the Reinforcement Learning.
#
#  Very soon, the data that is available these days has become so humongous that the conventional techniques developed so far failed to analyze the big data and provide us the predictions.
#
#  Thus, came the deep learning where the human brain is simulated in the Artificial Neural Networks (ANN) created in our binary computers.
#
#  The machine now learns on its own using the high computing power and huge memory resources that are available today.
#
#  It is now observed that Deep Learning has solved many of the previously unsolvable problems.
#
#  The technique is now further advanced by giving incentives to Deep Learning networks as awards and there finally comes Deep Reinforcement Learning.

# %% [markdown]
# # Supervised vs. Unsupervised

# %% [markdown]
# # ![pp.png](attachment:pp.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Unsupervised learning:
# Learning a model from unlabeled data.
#
# Algorithm is given data to automatically discover groupings or clusters in the data

# %% [markdown]
# # Supervised learning:
# Learning a model from labeled data.
#
# The algorithm is first given the right answers to leran and then used to predict the values.

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ![dw.png](attachment:dw.png)

# %% [markdown]
# # ![dew.png](attachment:dew.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Methods:
#
# K-means, gaussian mixtures, hierarchical clustering, spectral clustering, etc.

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Methods:
#
# Support Vector Machines, neural networks, decision trees, K-nearest neighbors, naive Bayes, etc.

# %% [markdown]
# # Classification
#
# Used to predict a discrete valued output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Regression
#
# Regression algorithm is used to predict a continuous valued output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Training and Testing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Overfitting/underfitting
# An intuitive example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Structural Risk Minimization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Avoid overfitting

# %% [markdown]
# In general, use simple models!
#
#  Reduce the number of features manually or do feature selection.
#
#  Do a model selection.
#
#  Use regularization (keep the features but reduce their importance by setting small parameter values).
#
#  Do a cross-validation to estimate the test error.

# %% [markdown]
# # Regularization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Train, Validation and Test Set

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Training set is a set of examples used for learning a model (e.g., a classification model).
#
# 2. Validation set is a set of examples that cannot be used for learning the model but can help tune model parameters (e.g., selecting K in KNN). Validation helps control overfitting.
#
# 3. Test set is used to assess the performance of the final model and provide an estimation of the test error.
#
# Note: Never use the test set in any way to further tune the parameters or revise the model.

# %% [markdown]
# # K Fold cross Validation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Confusion matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Evaluation metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Binary Classification Evaluation Metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Multiclass Classification Evaluation Metrics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Regression Evaluation Metrics

# %% [markdown]
# ![image.png](attachment:image.png)
