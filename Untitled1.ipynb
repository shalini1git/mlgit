# %%
list=['numpy', 'pandas', 'python', 'keras','numpy']
list.count('pandas')
# Out:
# 1

# %%
l1=[print("{} is Even Number".format(i)) if i % 2 == 0 else print("{} is odd number".format(i)) for i in range (10)]
# Out:
# 0 is Even Number
# 1 is odd number
# 2 is Even Number
# 3 is odd number
# 4 is Even Number
# 5 is odd number
# 6 is Even Number
# 7 is odd number
# 8 is Even Number
# 9 is odd number

# %%
myset3={10,20, "Hola", (11,22,32),22}
myset3
# Out:
# {(11, 22, 32), 10, 20, 22, 'Hola'}

# %%
myset=set()
print(type(myset))
# Out:
# <class 'set'>

# %%
keys={'a','b','d','c'}
mydict=dict.fromkeys(keys)
mydict
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
value=[2,10,30]
keys={'a','b','d','c'}
mydict=dict.fromkeys(keys,value)
mydict
# Out:
# {'a': [2, 10, 30], 'b': [2, 10, 30], 'c': [2, 10, 30], 'd': [2, 10, 30]}

# %%
value.append(50)
mydict
# Out:
# {'a': [2, 10, 30, 50, 50],
#  'b': [2, 10, 30, 50, 50],
#  'c': [2, 10, 30, 50, 50],
#  'd': [2, 10, 30, 50, 50]}

# %%
#lIST COMPREHENSION
#[expression for item in list]
#[num*2 for num in range(20)]
mylist=[i for i in range(10) if i%2==0]
mylist1=[i*i for i in range(10)]
print(mylist)
print(mylist1)
# Out:
# [0, 2, 4, 6, 8]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#DICTIONARY COMPREHENSION
#{key:value for var in iterable}
#{i:i*2 for i in range(10)}

# %%
import pandas as pd
import numpy as np

N=20

df = pd.DataFrame({
   'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
   'x': np.linspace(0,stop=N-1,num=N),
   'y': np.random.rand(N),
   'C': np.random.choice(['Low','Medium','High'],N).tolist(),
   'D': np.random.normal(100, 10, size=(N)).tolist()
})
print (df)
# Out:
#             A     x         y       C           D
# 0  2016-01-01   0.0  0.311110    High  102.925962
# 1  2016-01-02   1.0  0.677624    High   96.597044
# 2  2016-01-03   2.0  0.559383  Medium  106.368467
# 3  2016-01-04   3.0  0.103912  Medium   96.049373
# 4  2016-01-05   4.0  0.539496     Low  103.587179
# 5  2016-01-06   5.0  0.413838     Low   96.977947
# 6  2016-01-07   6.0  0.471827     Low   96.287300
# 7  2016-01-08   7.0  0.286202     Low  111.266017
# 8  2016-01-09   8.0  0.553792     Low   92.949573
# 9  2016-01-10   9.0  0.686614     Low  104.548147
# 10 2016-01-11  10.0  0.213282    High   87.431581
# 11 2016-01-12  11.0  0.495615    High  103.617861
# 12 2016-01-13  12.0  0.329564    High  118.848324
# 13 2016-01-14  13.0  0.521074  Medium  102.221135
# 14 2016-01-15  14.0  0.523027  Medium   85.432384
# 15 2016-01-16  15.0  0.271461    High  111.987510
# 16 2016-01-17  16.0  0.468450     Low  108.503523
# 17 2016-01-18  17.0  0.753841     Low  101.889476
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
import seaborn as sb
sb.set_style("ticks")
sb.set_context("notebook")
sinplot()
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
g = sb.FacetGrid(df, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip")
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
g = sb.PairGrid(df)
g.map(plt.scatter);
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
g = sb.PairGrid(df)
g.map_upper(plt.scatter)
g.map_lower(sb.kdeplot, cmap = "Greens_d")
g.map_diag(sb.kdeplot, lw = 8, legend = False);
plt.show()

# %%
import pandas as pd
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pd.read_csv("diabetes.csv")
df=data.skew()

plt.plot(df)
